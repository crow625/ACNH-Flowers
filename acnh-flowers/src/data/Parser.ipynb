# %% [markdown]
# # Parser
# ACNH Flowers by crow625
#
# In Animal Crossing: New Horizons, each flower has three (or four, in the case of roses) genes which can take values of 0, 1, or 2. The combination of these genes determines the color of the flower. When two flowers are selected to breed, each of their genes are passed down like real genes, which can be modeled by a Punnett Square. A 0 represents a recessive homozygous allele, a 1 represents a heterozygous allele, and a 2 represents a dominant homozygous allele.
#
# This file scrapes the animal crossing fandom wiki to retrieve the phenotypes of each flower based on their genes. For example, a rose with genes R1Y0W2B2 (red 1, yellow 0, white 2, brightness 2) is purple. The scraped data is stored in a csv file for use in the ACNH Flowers web app.
#
# Thank you to the contributors on animalcrossing.fandom.com.

# %% [markdown]
# This cell imports the required packages and saves the request from the website.

# %%
import pandas as pd
import requests
import bs4

url = "https://animalcrossing.fandom.com/wiki/Flowers/New_Horizons_mechanics"
response = requests.get(url)

# %% [markdown]
# This cell locates the two desired tables, the rose table and the 3-gene flower table, and saves them as variables.

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')
tables = soup.find_all(class_="roundy mw-collapsible")
rose_table = tables[0]
flower_table = tables[1]

# %% [markdown]
# The following two cells trim down the tables to be only the desired rows of the table (trimming headers and footers).

# %%
rose_table = rose_table.find_all("tr")
flower_table = flower_table.find_all("tr")

# %%
rose_table = rose_table[2:-1]
flower_table = flower_table[3:-1]

# %% [markdown]
# This cell defines a function to get the color of a flower from a string. The strings passed in are alt text for images of the flowers, since the tables on fandom use images rather than text to represent the flower colors.

# %%
def get_color(img_name):
    for color in ["white", "red", "yellow", "pink", "orange", "blue", "purple", "black", "green", "gold"]:
        if img_name.find(color) >= 0:
            return color
    return "unknown"

# %% [markdown]
# This cell defines a function to generate a flower's color string given its genes. For example, a flower with 0 red, 1 yellow, and 1 white will have color string R0Y1W1.

# %%
def color_string(red, yellow, white, b=None):
    if b != None:
        return "R" + str(red) + "Y" + str(yellow) + "W" + str(white) + "B" + str(b)
    return "R" + str(red) + "Y" + str(yellow) + "W" + str(white)

# %% [markdown]
# This cell initializes a place to store the data, then iterates over both tables simultaneously. In each iteration, it locates and stores the RYW values and saves the flower's color in its respective list. Roses are given three columns, one for each B value.
#
# Additionally, if the flower is a seed, it stores its genes in the seed table corresponding to its color and type.
# An exception is made for windflowers: since there is no yellow windflower, instead of a seed yellow, there is a seed orange. The genes of this seed orange are stored in the seeds table as if it were a seed yellow for the sake of restricting all the data to three colors.

# %%
data = {
    "red": [],
    "yellow": [],
    "white": [],
    "B0": [],
    "B1": [],
    "B2": [],
    "tulips": [],
    "pansies": [],
    "cosmos": [],
    "lilies": [],
    "hyacinths": [],
    "windflowers": [],
    "mums": []
}

seeds = {
    "red": {},
    "yellow": {},
    "white": {}
}
    
for flower_row in zip(rose_table, flower_table):
    roses = flower_row[0].find_all("td")
    flowers = flower_row[1].find_all("td")
    
    row = {}

    row["red"] = roses[0].text.strip()
    row["yellow"] = roses[1].text.strip()
    row["white"] = roses[2].text.strip()
    row["B0"] = roses[3]
    row["B1"] = roses[4]
    row["B2"] = roses[5]
    row["tulips"] = flowers[3]
    row["pansies"] = flowers[4]
    row["cosmos"] = flowers[5]
    row["lilies"] = flowers[6]
    row["hyacinths"] = flowers[7]
    row["windflowers"] = flowers[8]
    row["mums"] = flowers[9]
    
    for key in row.keys():
        # don't do any additional processing on the genes
        if (key == "red" or key == "yellow" or key == "white"):
            data[key].append(row[key])
        else:
            # fetch the flower's color and add it to the table
            color = get_color(row[key].find("img")["alt"])
            data[key].append(color)
            # if this is a seed flower, its background color will be #AED6F1
            if row[key]["style"].find("#AED6F1") >= 0:
                # if a rose, get the color string with a B value
                if key == "B0" or key == "B1" or key == "B2":
                    c_string = color_string(data["red"][-1], data["yellow"][-1], data["white"][-1], key[-1])
                    seeds[color]["roses"] = c_string
                # if not a rose, get the 3-gene color string
                else:
                    c_string = color_string(data["red"][-1], data["yellow"][-1], data["white"][-1])
                    # There is no seed yellow windflower (instead, there is a seed orange)
                    # So the seed orange is stored as yellow
                    if key == "windflowers" and color == "orange":
                        seeds["yellow"][key] = c_string
                    else:
                        seeds[color][key] = c_string

# %% [markdown]
# This cell converts the flower color data from the previous cell to a pandas dataframe and writes it to 'flowers.csv'

# %%
df = pd.DataFrame(data)
df.to_csv('flowers.csv', index=False)

# %% [markdown]
# This cell converts the flower seed data from the previous cell to a pandas dataframe and writes it to 'seeds.csv'

# %%
df = pd.DataFrame(seeds)
df.to_csv('seeds.csv', index=True)

# %% [markdown]
# The below cells load the csv data and convert it to json data so the acnh-flowers app can read it more easily.

# %%
import pandas as pd
import json
import numpy as np

flowers = pd.read_csv('flowers.csv')
seeds = pd.read_csv('seeds.csv')

# %%
flowers = flowers.rename({"B0": 'roses_B0', "B1": 'roses_B1', "B2": 'roses_B2'}, axis=1)
flowers
# Out:
#     red  yellow  white roses_B0 roses_B1 roses_B2  tulips pansies  cosmos
# 0     0       0      0    white    white    white   white   white   white  \
# 1     0       0      1    white    white    white   white   white   white
# 2     0       0      2   purple   purple   purple   white    blue   white
# 3     0       1      0   yellow   yellow   yellow  yellow  yellow  yellow
# 4     0       1      1    white    white    white  yellow  yellow  yellow
# 5     0       1      2   purple   purple   purple   white    blue   white
# 6     0       2      0   yellow   yellow   yellow  yellow  yellow  yellow
# 7     0       2      1   yellow   yellow   yellow  yellow  yellow  yellow
# 8     0       2      2    white    white    white  yellow  yellow  yellow
# 9     1       0      0      red     pink    white     red     red    pink
# 10    1       0      1      red     pink    white    pink     red    pink
# 11    1       0      2      red     pink   purple   white    blue    pink
# 12    1       1      0   orange   yellow   yellow  orange  orange  orange
# 13    1       1      1      red     pink    white  yellow  orange  orange
# 14    1       1      2      red     pink   purple  yellow  orange    pink
# 15    1       2      0   orange   yellow   yellow  orange  yellow  orange
# 16    1       2      1   orange   yellow   yellow  yellow  yellow  orange
# 17    1       2      2      red     pink    white  yellow  yellow  orange
# 18    2       0      0    black      red     pink   black     red     red
# 19    2       0      1    black      red     pink     red     red     red
# 20    2       0      2    black      red     pink     red  purple     red
# 21    2       1      0   orange   orange   yellow   black     red  orange
# 22    2       1      1      red      red    white     red     red  orange
# 23    2       1      2    black      red   purple     red  purple     red
# 24    2       2      0   orange   orange   yellow  purple  orange   black
# 25    2       2      1   orange   orange   yellow  purple  orange   black
# 26    2       2      2     blue      red    white  purple  purple     red
#
#     lilies hyacinths windflowers    mums
# 0    white     white       white   white
# 1    white     white       white   white
# 2    white      blue        blue  purple
# 3   yellow    yellow      orange  yellow
# 4    white    yellow      orange  yellow
# 5    white     white        blue   white
# 6   yellow    yellow      orange  yellow
# 7   yellow    yellow      orange  yellow
# 8    white    yellow      orange  yellow
# 9      red       red         red    pink
# 10    pink      pink         red    pink
# 11   white     white        blue    pink
# 12  orange    orange        pink  yellow
# 13  yellow    yellow        pink     red
# 14  yellow    yellow        pink    pink
# 15  orange    orange      orange  purple
# 16  yellow    yellow      orange  purple
# 17  yellow    yellow      orange  purple
# 18   black       red         red     red
# 19     red       red         red     red
# 20    pink       red      purple     red
# 21   black      blue         red  purple
# 22     red       red         red  purple
# 23    pink       red      purple     red
# 24  orange    purple        pink   green
# 25  orange    purple        pink   green
# 26   white    purple      purple     red

# %%
def stringFromGenes(r, y, w, b=None):
    output = "RrYyWw"
    output = output.replace("r", str(r))
    output = output.replace("y", str(y))
    output = output.replace("w", str(w))
    if b != None:
        output = output + "B" + str(b)
    return output

# %%
color_list = ["white", "red", "yellow", "pink", "orange", "blue", "purple", "black", "green", "gold"]

# %% [markdown]
# This cell populates the 'genes' array with mappings from each gene to its phenotype in each flower species.

# %%
# the json data that will be written to the file
data = {
    # maps a flower's type and color to a list of all possible genes with that phenotype
    'flowers': {
        col: {
            color: [] for color in color_list
        } for col in flowers.columns[3:]
    },
    # maps a gene string to the color it shows as in each flower type
    'genes': {},
    # maps a flower's type and color to the resulting gene string 
    'seeds': {}
}

flower_rows = flowers.to_dict(orient='records')

# Iterate over each set of genes
for row in flower_rows:
    gene_string = stringFromGenes(row['red'], row['yellow'], row['white'])
    gene_colors = {}
    # Iterate over each flower for that set of genes
    for flower in row.keys():
        if (flower != 'red' and flower != 'yellow' and flower != 'white'):
            gene_colors[flower] = row[flower]
            data['flowers'][flower][row[flower]].append(gene_string)
            
    data['genes'][gene_string] = gene_colors

# %% [markdown]
# This cell consolidates all the rose objects in the 'flowers' object ('roses_B0', 'roses_B1', 'roses_B2') into one 'roses' object

# %%
rose_colors = {}

for color in color_list:
    rose_colors[color] = []
    for key in list(data['flowers'].keys())[0:3]:
        for gene_string in data['flowers'][key][color]:
            new_gene_string = gene_string + key[-2:]
            rose_colors[color].append(new_gene_string)
    if len(rose_colors[color]) == 0:
        rose_colors.pop(color)
        
data['flowers']['roses'] = rose_colors
data['flowers'].pop('roses_B0')
data['flowers'].pop('roses_B1')
data['flowers'].pop('roses_B2')
# Out:
# {'white': ['R0Y0W0',
#   'R0Y0W1',
#   'R0Y1W1',
#   'R0Y2W2',
#   'R1Y0W0',
#   'R1Y0W1',
#   'R1Y1W1',
#   'R1Y2W2',
#   'R2Y1W1',
#   'R2Y2W2'],
#  'red': [],
#  'yellow': ['R0Y1W0',
#   'R0Y2W0',
#   'R0Y2W1',
#   'R1Y1W0',
#   'R1Y2W0',
#   'R1Y2W1',
#   'R2Y1W0',
#   'R2Y2W0',
#   'R2Y2W1'],
#  'pink': ['R2Y0W0', 'R2Y0W1', 'R2Y0W2'],
#  'orange': [],
#  'blue': [],
#  'purple': ['R0Y0W2', 'R0Y1W2', 'R1Y0W2', 'R1Y1W2', 'R2Y1W2'],
#  'black': [],
#  'green': [],
#  'gold': []}

# %%
seed_rows = seeds.to_dict(orient='records')
data['seeds'] = seed_rows

# %%
data
# Out:
# {'flowers': {'tulips': {'white': ['R0Y0W0',
#     'R0Y0W1',
#     'R0Y0W2',
#     'R0Y1W2',
#     'R1Y0W2'],
#    'red': ['R1Y0W0', 'R2Y0W1', 'R2Y0W2', 'R2Y1W1', 'R2Y1W2'],
#    'yellow': ['R0Y1W0',
#     'R0Y1W1',
#     'R0Y2W0',
#     'R0Y2W1',
#     'R0Y2W2',
#     'R1Y1W1',
#     'R1Y1W2',
#     'R1Y2W1',
#     'R1Y2W2'],
#    'pink': ['R1Y0W1'],
#    'orange': ['R1Y1W0', 'R1Y2W0'],
#    'blue': [],
#    'purple': ['R2Y2W0', 'R2Y2W1', 'R2Y2W2'],
#    'black': ['R2Y0W0', 'R2Y1W0'],
#    'green': [],
#    'gold': []},
#   'pansies': {'white': ['R0Y0W0', 'R0Y0W1'],
#    'red': ['R1Y0W0', 'R1Y0W1', 'R2Y0W0', 'R2Y0W1', 'R2Y1W0', 'R2Y1W1'],
#    'yellow': ['R0Y1W0',
#     'R0Y1W1',
#     'R0Y2W0',
#     'R0Y2W1',
#     'R0Y2W2',
#     'R1Y2W0',
#     'R1Y2W1',
#     'R1Y2W2'],
#    'pink': [],
#    'orange': ['R1Y1W0', 'R1Y1W1', 'R1Y1W2', 'R2Y2W0', 'R2Y2W1'],
#    'blue': ['R0Y0W2', 'R0Y1W2', 'R1Y0W2'],
#    'purple': ['R2Y0W2', 'R2Y1W2', 'R2Y2W2'],
#    'black': [],
#    'green': [],
#    'gold': []},
#   'cosmos': {'white': ['R0Y0W0', 'R0Y0W1', 'R0Y0W2', 'R0Y1W2'],
#    'red': ['R2Y0W0', 'R2Y0W1', 'R2Y0W2', 'R2Y1W2', 'R2Y2W2'],
#    'yellow': ['R0Y1W0', 'R0Y1W1', 'R0Y2W0', 'R0Y2W1', 'R0Y2W2'],
#    'pink': ['R1Y0W0', 'R1Y0W1', 'R1Y0W2', 'R1Y1W2'],
#    'orange': ['R1Y1W0',
#     'R1Y1W1',
#     'R1Y2W0',
#     'R1Y2W1',
#     'R1Y2W2',
#     'R2Y1W0',
#     'R2Y1W1'],
#    'blue': [],
#    'purple': [],
#    'black': ['R2Y2W0', 'R2Y2W1'],
#    'green': [],
#    'gold': []},
#   'lilies': {'white': ['R0Y0W0',
#     'R0Y0W1',
#     'R0Y0W2',
#     'R0Y1W1',
#     'R0Y1W2',
#     'R0Y2W2',
#     'R1Y0W2',
#     'R2Y2W2'],
#    'red': ['R1Y0W0', 'R2Y0W1', 'R2Y1W1'],
#    'yellow': ['R0Y1W0',
#     'R0Y2W0',
#     'R0Y2W1',
#     'R1Y1W1',
#     'R1Y1W2',
#     'R1Y2W1',
#     'R1Y2W2'],
#    'pink': ['R1Y0W1', 'R2Y0W2', 'R2Y1W2'],
#    'orange': ['R1Y1W0', 'R1Y2W0', 'R2Y2W0', 'R2Y2W1'],
#    'blue': [],
#    'purple': [],
#    'black': ['R2Y0W0', 'R2Y1W0'],
#    'green': [],
#    'gold': []},
#   'hyacinths': {'white': ['R0Y0W0', 'R0Y0W1', 'R0Y1W2', 'R1Y0W2'],
#    'red': ['R1Y0W0', 'R2Y0W0', 'R2Y0W1', 'R2Y0W2', 'R2Y1W1', 'R2Y1W2'],
#    'yellow': ['R0Y1W0',
#     'R0Y1W1',
#     'R0Y2W0',
#     'R0Y2W1',
#     'R0Y2W2',
#     'R1Y1W1',
#     'R1Y1W2',
#     'R1Y2W1',
#     'R1Y2W2'],
#    'pink': ['R1Y0W1'],
#    'orange': ['R1Y1W0', 'R1Y2W0'],
#    'blue': ['R0Y0W2', 'R2Y1W0'],
#    'purple': ['R2Y2W0', 'R2Y2W1', 'R2Y2W2'],
#    'black': [],
#    'green': [],
#    'gold': []},
#   'windflowers': {'white': ['R0Y0W0', 'R0Y0W1'],
#    'red': ['R1Y0W0', 'R1Y0W1', 'R2Y0W0', 'R2Y0W1', 'R2Y1W0', 'R2Y1W1'],
#    'yellow': [],
#    'pink': ['R1Y1W0', 'R1Y1W1', 'R1Y1W2', 'R2Y2W0', 'R2Y2W1'],
#    'orange': ['R0Y1W0',
#     'R0Y1W1',
#     'R0Y2W0',
#     'R0Y2W1',
#     'R0Y2W2',
#     'R1Y2W0',
#     'R1Y2W1',
#     'R1Y2W2'],
#    'blue': ['R0Y0W2', 'R0Y1W2', 'R1Y0W2'],
#    'purple': ['R2Y0W2', 'R2Y1W2', 'R2Y2W2'],
#    'black': [],
#    'green': [],
#    'gold': []},
#   'mums': {'white': ['R0Y0W0', 'R0Y0W1', 'R0Y1W2'],
#    'red': ['R1Y1W1', 'R2Y0W0', 'R2Y0W1', 'R2Y0W2', 'R2Y1W2', 'R2Y2W2'],
#    'yellow': ['R0Y1W0', 'R0Y1W1', 'R0Y2W0', 'R0Y2W1', 'R0Y2W2', 'R1Y1W0'],
#    'pink': ['R1Y0W0', 'R1Y0W1', 'R1Y0W2', 'R1Y1W2'],
#    'orange': [],
#    'blue': [],
#    'purple': ['R0Y0W2', 'R1Y2W0', 'R1Y2W1', 'R1Y2W2', 'R2Y1W0', 'R2Y1W1'],
#    'black': [],
#    'green': ['R2Y2W0', 'R2Y2W1'],
#    'gold': []},
#   'roses': {'white': ['R0Y0W0B0',
#     'R0Y0W1B0',
#     'R0Y1W1B0',
#     'R0Y2W2B0',
#     'R0Y0W0B1',
#     'R0Y0W1B1',
#     'R0Y1W1B1',
#     'R0Y2W2B1',
#     'R0Y0W0B2',
#     'R0Y0W1B2',
#     'R0Y1W1B2',
#     'R0Y2W2B2',
#     'R1Y0W0B2',
#     'R1Y0W1B2',
#     'R1Y1W1B2',
#     'R1Y2W2B2',
#     'R2Y1W1B2',
#     'R2Y2W2B2'],
#    'red': ['R1Y0W0B0',
#     'R1Y0W1B0',
#     'R1Y0W2B0',
#     'R1Y1W1B0',
#     'R1Y1W2B0',
#     'R1Y2W2B0',
#     'R2Y1W1B0',
#     'R2Y0W0B1',
#     'R2Y0W1B1',
#     'R2Y0W2B1',
#     'R2Y1W1B1',
#     'R2Y1W2B1',
#     'R2Y2W2B1'],
#    'yellow': ['R0Y1W0B0',
#     'R0Y2W0B0',
#     'R0Y2W1B0',
#     'R0Y1W0B1',
#     'R0Y2W0B1',
#     'R0Y2W1B1',
#     'R1Y1W0B1',
#     'R1Y2W0B1',
#     'R1Y2W1B1',
#     'R0Y1W0B2',
#     'R0Y2W0B2',
#     'R0Y2W1B2',
#     'R1Y1W0B2',
#     'R1Y2W0B2',
#     'R1Y2W1B2',
#     'R2Y1W0B2',
#     'R2Y2W0B2',
#     'R2Y2W1B2'],
#    'pink': ['R1Y0W0B1',
#     'R1Y0W1B1',
#     'R1Y0W2B1',
#     'R1Y1W1B1',
#     'R1Y1W2B1',
#     'R1Y2W2B1',
#     'R2Y0W0B2',
#     'R2Y0W1B2',
#     'R2Y0W2B2'],
#    'orange': ['R1Y1W0B0',
#     'R1Y2W0B0',
#     'R1Y2W1B0',
#     'R2Y1W0B0',
#     'R2Y2W0B0',
#     'R2Y2W1B0',
#     'R2Y1W0B1',
#     'R2Y2W0B1',
#     'R2Y2W1B1'],
#    'blue': ['R2Y2W2B0'],
#    'purple': ['R0Y0W2B0',
#     'R0Y1W2B0',
#     'R0Y0W2B1',
#     'R0Y1W2B1',
#     'R0Y0W2B2',
#     'R0Y1W2B2',
#     'R1Y0W2B2',
#     'R1Y1W2B2',
#     'R2Y1W2B2'],
#    'black': ['R2Y0W0B0', 'R2Y0W1B0', 'R2Y0W2B0', 'R2Y1W2B0']}},
#  'genes': {'R0Y0W0': {'roses_B0': 'white',
#    'roses_B1': 'white',
#    'roses_B2': 'white',
#    'tulips': 'white',
#    'pansies': 'white',
#    'cosmos': 'white',
#    'lilies': 'white',
#    'hyacinths': 'white',
#    'windflowers': 'white',
#    'mums': 'white'},
#   'R0Y0W1': {'roses_B0': 'white',
#    'roses_B1': 'white',
#    'roses_B2': 'white',
#    'tulips': 'white',
#    'pansies': 'white',
#    'cosmos': 'white',
#    'lilies': 'white',
#    'hyacinths': 'white',
#    'windflowers': 'white',
#    'mums': 'white'},
#   'R0Y0W2': {'roses_B0': 'purple',
#    'roses_B1': 'purple',
#    'roses_B2': 'purple',
#    'tulips': 'white',
#    'pansies': 'blue',
#    'cosmos': 'white',
#    'lilies': 'white',
#    'hyacinths': 'blue',
#    'windflowers': 'blue',
#    'mums': 'purple'},
#   'R0Y1W0': {'roses_B0': 'yellow',
#    'roses_B1': 'yellow',
#    'roses_B2': 'yellow',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'yellow',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'yellow'},
#   'R0Y1W1': {'roses_B0': 'white',
#    'roses_B1': 'white',
#    'roses_B2': 'white',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'yellow',
#    'lilies': 'white',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'yellow'},
#   'R0Y1W2': {'roses_B0': 'purple',
#    'roses_B1': 'purple',
#    'roses_B2': 'purple',
#    'tulips': 'white',
#    'pansies': 'blue',
#    'cosmos': 'white',
#    'lilies': 'white',
#    'hyacinths': 'white',
#    'windflowers': 'blue',
#    'mums': 'white'},
#   'R0Y2W0': {'roses_B0': 'yellow',
#    'roses_B1': 'yellow',
#    'roses_B2': 'yellow',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'yellow',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'yellow'},
#   'R0Y2W1': {'roses_B0': 'yellow',
#    'roses_B1': 'yellow',
#    'roses_B2': 'yellow',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'yellow',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'yellow'},
#   'R0Y2W2': {'roses_B0': 'white',
#    'roses_B1': 'white',
#    'roses_B2': 'white',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'yellow',
#    'lilies': 'white',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'yellow'},
#   'R1Y0W0': {'roses_B0': 'red',
#    'roses_B1': 'pink',
#    'roses_B2': 'white',
#    'tulips': 'red',
#    'pansies': 'red',
#    'cosmos': 'pink',
#    'lilies': 'red',
#    'hyacinths': 'red',
#    'windflowers': 'red',
#    'mums': 'pink'},
#   'R1Y0W1': {'roses_B0': 'red',
#    'roses_B1': 'pink',
#    'roses_B2': 'white',
#    'tulips': 'pink',
#    'pansies': 'red',
#    'cosmos': 'pink',
#    'lilies': 'pink',
#    'hyacinths': 'pink',
#    'windflowers': 'red',
#    'mums': 'pink'},
#   'R1Y0W2': {'roses_B0': 'red',
#    'roses_B1': 'pink',
#    'roses_B2': 'purple',
#    'tulips': 'white',
#    'pansies': 'blue',
#    'cosmos': 'pink',
#    'lilies': 'white',
#    'hyacinths': 'white',
#    'windflowers': 'blue',
#    'mums': 'pink'},
#   'R1Y1W0': {'roses_B0': 'orange',
#    'roses_B1': 'yellow',
#    'roses_B2': 'yellow',
#    'tulips': 'orange',
#    'pansies': 'orange',
#    'cosmos': 'orange',
#    'lilies': 'orange',
#    'hyacinths': 'orange',
#    'windflowers': 'pink',
#    'mums': 'yellow'},
#   'R1Y1W1': {'roses_B0': 'red',
#    'roses_B1': 'pink',
#    'roses_B2': 'white',
#    'tulips': 'yellow',
#    'pansies': 'orange',
#    'cosmos': 'orange',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'pink',
#    'mums': 'red'},
#   'R1Y1W2': {'roses_B0': 'red',
#    'roses_B1': 'pink',
#    'roses_B2': 'purple',
#    'tulips': 'yellow',
#    'pansies': 'orange',
#    'cosmos': 'pink',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'pink',
#    'mums': 'pink'},
#   'R1Y2W0': {'roses_B0': 'orange',
#    'roses_B1': 'yellow',
#    'roses_B2': 'yellow',
#    'tulips': 'orange',
#    'pansies': 'yellow',
#    'cosmos': 'orange',
#    'lilies': 'orange',
#    'hyacinths': 'orange',
#    'windflowers': 'orange',
#    'mums': 'purple'},
#   'R1Y2W1': {'roses_B0': 'orange',
#    'roses_B1': 'yellow',
#    'roses_B2': 'yellow',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'orange',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'purple'},
#   'R1Y2W2': {'roses_B0': 'red',
#    'roses_B1': 'pink',
#    'roses_B2': 'white',
#    'tulips': 'yellow',
#    'pansies': 'yellow',
#    'cosmos': 'orange',
#    'lilies': 'yellow',
#    'hyacinths': 'yellow',
#    'windflowers': 'orange',
#    'mums': 'purple'},
#   'R2Y0W0': {'roses_B0': 'black',
#    'roses_B1': 'red',
#    'roses_B2': 'pink',
#    'tulips': 'black',
#    'pansies': 'red',
#    'cosmos': 'red',
#    'lilies': 'black',
#    'hyacinths': 'red',
#    'windflowers': 'red',
#    'mums': 'red'},
#   'R2Y0W1': {'roses_B0': 'black',
#    'roses_B1': 'red',
#    'roses_B2': 'pink',
#    'tulips': 'red',
#    'pansies': 'red',
#    'cosmos': 'red',
#    'lilies': 'red',
#    'hyacinths': 'red',
#    'windflowers': 'red',
#    'mums': 'red'},
#   'R2Y0W2': {'roses_B0': 'black',
#    'roses_B1': 'red',
#    'roses_B2': 'pink',
#    'tulips': 'red',
#    'pansies': 'purple',
#    'cosmos': 'red',
#    'lilies': 'pink',
#    'hyacinths': 'red',
#    'windflowers': 'purple',
#    'mums': 'red'},
#   'R2Y1W0': {'roses_B0': 'orange',
#    'roses_B1': 'orange',
#    'roses_B2': 'yellow',
#    'tulips': 'black',
#    'pansies': 'red',
#    'cosmos': 'orange',
#    'lilies': 'black',
#    'hyacinths': 'blue',
#    'windflowers': 'red',
#    'mums': 'purple'},
#   'R2Y1W1': {'roses_B0': 'red',
#    'roses_B1': 'red',
#    'roses_B2': 'white',
#    'tulips': 'red',
#    'pansies': 'red',
#    'cosmos': 'orange',
#    'lilies': 'red',
#    'hyacinths': 'red',
#    'windflowers': 'red',
#    'mums': 'purple'},
#   'R2Y1W2': {'roses_B0': 'black',
#    'roses_B1': 'red',
#    'roses_B2': 'purple',
#    'tulips': 'red',
#    'pansies': 'purple',
#    'cosmos': 'red',
#    'lilies': 'pink',
#    'hyacinths': 'red',
#    'windflowers': 'purple',
#    'mums': 'red'},
#   'R2Y2W0': {'roses_B0': 'orange',
#    'roses_B1': 'orange',
#    'roses_B2': 'yellow',
#    'tulips': 'purple',
#    'pansies': 'orange',
#    'cosmos': 'black',
#    'lilies': 'orange',
#    'hyacinths': 'purple',
#    'windflowers': 'pink',
#    'mums': 'green'},
#   'R2Y2W1': {'roses_B0': 'orange',
#    'roses_B1': 'orange',
#    'roses_B2': 'yellow',
#    'tulips': 'purple',
#    'pansies': 'orange',
#    'cosmos': 'black',
#    'lilies': 'orange',
#    'hyacinths': 'purple',
#    'windflowers': 'pink',
#    'mums': 'green'},
#   'R2Y2W2': {'roses_B0': 'blue',
#    'roses_B1': 'red',
#    'roses_B2': 'white',
#    'tulips': 'purple',
#    'pansies': 'purple',
#    'cosmos': 'red',
#    'lilies': 'white',
#    'hyacinths': 'purple',
#    'windflowers': 'purple',
#    'mums': 'red'}},
#  'seeds': [{'flower': 'roses',
#    'red': 'R2Y0W0B1',
#    'yellow': 'R0Y2W0B0',
#    'white': 'R0Y0W1B0'},
#   {'flower': 'pansies',
#    'red': 'R2Y0W0',
#    'yellow': 'R0Y2W0',
#    'white': 'R0Y0W1'},
#   {'flower': 'cosmos', 'red': 'R2Y0W0', 'yellow': 'R0Y2W1', 'white': 'R0Y0W1'},
#   {'flower': 'windflowers',
#    'red': 'R2Y0W0',
#    'yellow': 'R0Y2W0',
#    'white': 'R0Y0W1'},
#   {'flower': 'mums', 'red': 'R2Y0W0', 'yellow': 'R0Y2W0', 'white': 'R0Y0W1'},
#   {'flower': 'tulips', 'red': 'R2Y0W1', 'yellow': 'R0Y2W0', 'white': 'R0Y0W1'},
#   {'flower': 'lilies', 'red': 'R2Y0W1', 'yellow': 'R0Y2W0', 'white': 'R0Y0W2'},
#   {'flower': 'hyacinths',
#    'red': 'R2Y0W1',
#    'yellow': 'R0Y2W0',
#    'white': 'R0Y0W1'}]}

# %%
with open('data.json', 'w') as out_file:
    json.dump(data, out_file, indent=4)
